# %%
import pandas as pd
import json

from bs4 import BeautifulSoup
import re

# %%
before = '../data/raw/Raw_tweets_DonaldTrump_before_elec.json'
after = '../data/raw/Raw_tweets_DonaldTrump_after_elec.json'

df_before = pd.read_json(open(before, 'r'))
df_after = pd.read_json(open(after, 'r'))

# %%
# Tässä on nyt ylimääräisiä twiittejä ja ne ovat epäkronologisessa järjestyksessä.
print(df_before.iloc[1000])
df_before
# Out:
# created_at             datetime.datetime(2016, 8, 20, 5, 2, 57)
# text          "@CatOnGlass: 200,000 new followers for @realD...
# Name: 1000, dtype: object
#                                        created_at  \
# 0      datetime.datetime(2016, 11, 6, 19, 26, 58)
# 1       datetime.datetime(2016, 11, 6, 18, 9, 44)
# 2        datetime.datetime(2016, 11, 6, 17, 6, 8)
# 3        datetime.datetime(2016, 11, 6, 6, 8, 32)
# 4           datetime.datetime(2016, 11, 6, 4, 27)
# 5        datetime.datetime(2016, 11, 6, 2, 3, 20)
# 6       datetime.datetime(2016, 11, 6, 0, 20, 16)
# 7       datetime.datetime(2016, 11, 6, 0, 19, 18)
# 8      datetime.datetime(2016, 11, 5, 21, 46, 34)
# 9      datetime.datetime(2016, 11, 5, 21, 39, 44)
# 10      datetime.datetime(2016, 11, 5, 21, 38, 1)
# 11     datetime.datetime(2016, 11, 5, 21, 27, 32)
# 12     datetime.datetime(2016, 11, 5, 20, 13, 34)
# 13      datetime.datetime(2016, 11, 5, 20, 6, 21)
# 14      datetime.datetime(2016, 11, 5, 16, 45, 5)
# ...

# %%
#example how to parse the nice datetime.datetime string...
from datetime import datetime

time = df_before["created_at"][0]
print(time,type(time))
time = time[18:]
print(time)
t = datetime.strptime(time[:len(time)-1], "%Y, %m, %d, %H, %M, %S")
print(t, type(t))

def parse_to_datetime(time_string):
    time = time_string[18:]
    try:
        t = datetime.strptime(time[:len(time)-1], "%Y, %m, %d, %H, %M, %S")
    except ValueError:
        #print("Taivas varjele mikä sieltä tulee!!! Sekunnit puuttuu", time)
        t = datetime.strptime(time[:len(time)-1], "%Y, %m, %d, %H, %M")
        
    return t
# Out:
# datetime.datetime(2016, 11, 6, 19, 26, 58) <class 'str'>
# 2016, 11, 6, 19, 26, 58)
# 2016-11-06 19:26:58 <class 'datetime.datetime'>

# %%
#change the timestamps to pd.Timestamps
new_df_before = df_before.copy()
for i, time in enumerate(df_before["created_at"]):
    #parse time to datetime
    t = parse_to_datetime(time)
    #change it to pd.Timestamp
    t = pd.Timestamp.fromtimestamp(t.timestamp())
    new_df_before["created_at"][i] = t
    
new_df_before
# Out:
#                 created_at                                               text
# 0      2016-11-06 19:26:58  Thank you Iowa - Get out &amp; #VoteTrumpPence...
# 1      2016-11-06 18:09:44  RT @IvankaTrump: Thank you New Hampshire! ????...
# 2      2016-11-06 17:06:08  Van Jones: ‘There Is A Crack in the Blue Wall’...
# 3      2016-11-06 06:08:32  Great night in Denver, Colorado- thank you! To...
# 4      2016-11-06 04:27:00  RT @DanScavino: Join @realDonaldTrump LIVE in ...
# 5      2016-11-06 02:03:20  Thank you Reno, Nevada. \nNOTHING will stop us...
# 6      2016-11-06 00:20:16  Join me live in Reno, Nevada!\nhttps://t.co/T4...
# 7      2016-11-06 00:19:18  JOIN ME TOMORROW!\nMINNESOTA • 2pm\nhttps://t....
# 8      2016-11-05 21:46:34           #DrainTheSwamp!\nhttps://t.co/z68vGp9Bvf
# 9      2016-11-05 21:39:44  Top Clinton Aides Bemoan Campaign ‘All Tactics...
# 10     2016-11-05 21:38:01  ‘Must Act Immediately’: Clinton Charity Lawyer...
# ...

# %%
#change the timestamps to pd.Timestamps
new_df_after = df_after.copy()
for i, time in enumerate(df_after["created_at"]):
    #parse time to datetime
    t = parse_to_datetime(time)
    #change it to pd.Timestamp
    t = pd.Timestamp.fromtimestamp(t.timestamp())
    new_df_after["created_at"][i] = t
    
new_df_after
# Out:
#                created_at                                               text
# 0     2017-10-06 02:16:32  RT @FoxBusiness: #StockAlert: U.S. markets sin...
# 1     2017-10-06 02:15:36  RT @Scavino45: .@POTUS @realDonaldTrump in the...
# 2     2017-10-06 01:58:27  Ralph Northam,who is running for Governor of V...
# 3     2017-10-05 11:50:56  Rex Tillerson never threatened to resign. This...
# 4     2017-10-05 11:09:50  Stock Market hits an ALL-TIME high! Unemployme...
# 5     2017-10-05 10:59:40  Why Isn't the Senate Intel Committee looking i...
# 6     2017-10-05 10:46:02                 Thank you! https://t.co/YMuqSvvTSB
# 7     2017-10-05 10:44:19  So wonderful to be in Las Vegas yesterday and ...
# 8     2017-10-05 10:34:12  RT @ABC: Pres. Trump: "We cannot be defined by...
# 9     2017-10-05 10:31:39  RT @Scavino45: .@POTUS &amp; @FLOTUS w/ @LVMPD...
# 10    2017-10-05 10:31:24  RT @Scavino45: .@POTUS @realDonaldTrump and @F...
# ...

# %%
#after wrangling, let's update the original object and sort it by timestamps
df_before = new_df_before.sort_values(by="created_at")
df_before = df_before.reset_index(drop=True)
df_before
# Out:
#                 created_at                                               text
# 0      2015-06-14 21:15:20  "@justrelaxfornow: As a nation yearns for just...
# 1      2015-06-14 21:18:23  Tuesday will be a big day for our country to d...
# 2      2015-06-15 11:12:50  Tomorrow will be a really big day for America....
# 3      2015-06-15 11:30:53  "@FuturisticHub: @realDonaldTrump I'd vote twi...
# 4      2015-06-15 11:40:27  "@MediciMario: @realDonaldTrump Pls run u woul...
# 5      2015-06-15 11:41:38  "@fyrftr211: @realDonaldTrump #Trump2016. Time...
# 6      2015-06-15 11:43:17  "@ZStr8Up: After the liberal 60's and 70's how...
# 7      2015-06-15 11:43:49  "@LooneyTunes002: Politicians are not going to...
# 8      2015-06-15 11:51:49  "@Subdoc101:Trump said on @foxandfriends today...
# 9      2015-06-15 14:28:43  Tomorrow at 11AM #MakeAmericaGreatAgain https:...
# 10     2015-06-15 14:55:16         LIVE on #Periscope https://t.co/H8lRtZBGEb
# ...

# %%
df_after = new_df_after.sort_values(by="created_at")
df_after = df_after.reset_index(drop=True)
df_after
# Out:
#                created_at                                               text
# 0     2016-11-07 22:21:53  Hey Missouri let's defeat Crooked Hillary &amp...
# 1     2016-11-07 23:28:48  LIVE on #Periscope: Join me for a few minutes ...
# 2     2016-11-08 00:08:28  Thank you Pennsylvania! Going to New Hampshire...
# 3     2016-11-08 00:16:15  Today in Florida, I pledged to stand with the ...
# 4     2016-11-08 00:17:57  Big news to share in New Hampshire tonight! Po...
# 5     2016-11-08 03:43:54  Unbelievable evening in New Hampshire - THANK ...
# 6     2016-11-08 04:27:18  RT @detroitnews: .@IvankaTrump in Michigan: ‘T...
# 7     2016-11-08 04:29:10  RT @DonaldJTrumpJr: Thanks New Hampshire!!! \n...
# 8     2016-11-08 06:42:36  Today we are going to win the great state of M...
# 9     2016-11-08 11:43:14                 TODAY WE MAKE AMERICA GREAT AGAIN!
# 10    2016-11-08 16:39:36  VOTE TODAY! Go to https://t.co/MXrAxYnTjY to f...
# ...

# %%
#remove the tweets from "before" that are not "before"
#trump was elected on the 8th of Nov 2016

#first find out the right index the stupid way
for i in range(7700,7800,1):
    print(df_before.iloc[i])
    
# --> ind = 10309

ind = 7793
# Out:
# created_at                                  2016-10-29 13:08:22
# text          I am in Colorado - big day planned - but nothi...
# Name: 7700, dtype: object
# created_at                                  2016-10-29 15:37:26
# text          "@DeplorableCBTP: "In my mind, #DonaldTrump is...
# Name: 7701, dtype: object
# created_at                                  2016-10-29 16:54:54
# text          Tomorrow!\n\nLas Vegas, NV- 11a: https://t.co/...
# Name: 7702, dtype: object
# created_at                       2016-10-29 17:02:04
# text          #ObamacareFail https://t.co/iusXk4n9w7
# Name: 7703, dtype: object
# created_at                                  2016-10-29 19:56:49
# text          Departing Golden, CO. for Arizona now - after ...
# Name: 7704, dtype: object
# created_at                                  2016-10-29 20:02:16
# text          So nice - great Americans outside Trump Tower ...
# Name: 7705, dtype: object
# ...

# %%
#then remove the unnessessary tweets
print(df_before.shape)
df_before = df_before[:ind]
print(df_before.shape)
df_before
# Out:
# (13132, 2)
# (7793, 2)
#                created_at                                               text
# 0     2015-06-14 21:15:20  "@justrelaxfornow: As a nation yearns for just...
# 1     2015-06-14 21:18:23  Tuesday will be a big day for our country to d...
# 2     2015-06-15 11:12:50  Tomorrow will be a really big day for America....
# 3     2015-06-15 11:30:53  "@FuturisticHub: @realDonaldTrump I'd vote twi...
# 4     2015-06-15 11:40:27  "@MediciMario: @realDonaldTrump Pls run u woul...
# 5     2015-06-15 11:41:38  "@fyrftr211: @realDonaldTrump #Trump2016. Time...
# 6     2015-06-15 11:43:17  "@ZStr8Up: After the liberal 60's and 70's how...
# 7     2015-06-15 11:43:49  "@LooneyTunes002: Politicians are not going to...
# 8     2015-06-15 11:51:49  "@Subdoc101:Trump said on @foxandfriends today...
# 9     2015-06-15 14:28:43  Tomorrow at 11AM #MakeAmericaGreatAgain https:...
# 10    2015-06-15 14:55:16         LIVE on #Periscope https://t.co/H8lRtZBGEb
# ...

# %%
#remove also two unnessessary tweets from after-set
print(df_after.shape)
df_after2 = df_after[2:]
print(df_after2.shape)
df_after2
# Out:
# (5341, 2)
# (5339, 2)
#                created_at                                               text
# 2     2016-11-08 00:08:28  Thank you Pennsylvania! Going to New Hampshire...
# 3     2016-11-08 00:16:15  Today in Florida, I pledged to stand with the ...
# 4     2016-11-08 00:17:57  Big news to share in New Hampshire tonight! Po...
# 5     2016-11-08 03:43:54  Unbelievable evening in New Hampshire - THANK ...
# 6     2016-11-08 04:27:18  RT @detroitnews: .@IvankaTrump in Michigan: ‘T...
# 7     2016-11-08 04:29:10  RT @DonaldJTrumpJr: Thanks New Hampshire!!! \n...
# 8     2016-11-08 06:42:36  Today we are going to win the great state of M...
# 9     2016-11-08 11:43:14                 TODAY WE MAKE AMERICA GREAT AGAIN!
# 10    2016-11-08 16:39:36  VOTE TODAY! Go to https://t.co/MXrAxYnTjY to f...
# 11    2016-11-08 18:03:49  We need your vote. Go to the POLLS! Let's cont...
# 12    2016-11-08 18:23:39  #ElectionDay https://t.co/MXrAxYnTjY https://t...
# ...

# %%
#fix the indices again
df_after = df_after2.sort_values(by="created_at")
df_after = df_after.reset_index(drop=True)
df_after
# Out:
#                created_at                                               text
# 0     2016-11-08 00:08:28  Thank you Pennsylvania! Going to New Hampshire...
# 1     2016-11-08 00:16:15  Today in Florida, I pledged to stand with the ...
# 2     2016-11-08 00:17:57  Big news to share in New Hampshire tonight! Po...
# 3     2016-11-08 03:43:54  Unbelievable evening in New Hampshire - THANK ...
# 4     2016-11-08 04:27:18  RT @detroitnews: .@IvankaTrump in Michigan: ‘T...
# 5     2016-11-08 04:29:10  RT @DonaldJTrumpJr: Thanks New Hampshire!!! \n...
# 6     2016-11-08 06:42:36  Today we are going to win the great state of M...
# 7     2016-11-08 11:43:14                 TODAY WE MAKE AMERICA GREAT AGAIN!
# 8     2016-11-08 16:39:36  VOTE TODAY! Go to https://t.co/MXrAxYnTjY to f...
# 9     2016-11-08 18:03:49  We need your vote. Go to the POLLS! Let's cont...
# 10    2016-11-08 18:23:39  #ElectionDay https://t.co/MXrAxYnTjY https://t...
# ...

# %%
# Join dataferames
big_df = df_before.append(df_after)
df = big_df.reset_index()
del df['index']
df
# Out:
#                 created_at                                               text
# 0      2015-06-14 21:15:20  "@justrelaxfornow: As a nation yearns for just...
# 1      2015-06-14 21:18:23  Tuesday will be a big day for our country to d...
# 2      2015-06-15 11:12:50  Tomorrow will be a really big day for America....
# 3      2015-06-15 11:30:53  "@FuturisticHub: @realDonaldTrump I'd vote twi...
# 4      2015-06-15 11:40:27  "@MediciMario: @realDonaldTrump Pls run u woul...
# 5      2015-06-15 11:41:38  "@fyrftr211: @realDonaldTrump #Trump2016. Time...
# 6      2015-06-15 11:43:17  "@ZStr8Up: After the liberal 60's and 70's how...
# 7      2015-06-15 11:43:49  "@LooneyTunes002: Politicians are not going to...
# 8      2015-06-15 11:51:49  "@Subdoc101:Trump said on @foxandfriends today...
# 9      2015-06-15 14:28:43  Tomorrow at 11AM #MakeAmericaGreatAgain https:...
# 10     2015-06-15 14:55:16         LIVE on #Periscope https://t.co/H8lRtZBGEb
# ...

# %%
#Make the before-set same size than after-set
size = 5339 
ind = 7793-size
df_before2 = df_before[ind:]
df_before2
# Out:
#                created_at                                               text
# 2454  2015-10-25 13:46:08  "@msbul: Your a gentlemen Ben but not our next...
# 2455  2015-10-25 13:48:35  "@russia890: @CNNPolitics @realDonaldTrump Tru...
# 2456  2015-10-25 13:55:58  "@ron_fournier: .@realDonaldTrump rightly deno...
# 2457  2015-10-25 14:22:31  "@MachadoKirk: @StrengthenTheUS  @realDonaldTr...
# 2458  2015-10-25 14:29:51  Watch my interview on @CBSNews Face The Nation...
# 2459  2015-10-25 16:11:58  .@CBSNews Poll - WOW!  New Hampshire  TRUMP 38...
# 2460  2015-10-25 17:53:31  Do you believe that @FoxNews is still playing ...
# 2461  2015-10-25 18:36:34  .@ByronYork  Great numbers from @CBSNews Poll....
# 2462  2015-10-25 18:46:26  "@thatgirlflorida: @realDonaldTrump @ByronYork...
# 2463  2015-10-25 18:54:50  "@concerningtimes: @JebBush needs to drop out ...
# 2464  2015-10-25 18:55:36  "@Tirolian2: @realDonaldTrump @ByronYork @CBSN...
# ...

# %%
#fix the indices one last time
df_before = df_before2.sort_values(by="created_at")
df_before = df_before.reset_index(drop=True)
df_before
# Out:
#                created_at                                               text
# 0     2015-10-25 13:46:08  "@msbul: Your a gentlemen Ben but not our next...
# 1     2015-10-25 13:48:35  "@russia890: @CNNPolitics @realDonaldTrump Tru...
# 2     2015-10-25 13:55:58  "@ron_fournier: .@realDonaldTrump rightly deno...
# 3     2015-10-25 14:22:31  "@MachadoKirk: @StrengthenTheUS  @realDonaldTr...
# 4     2015-10-25 14:29:51  Watch my interview on @CBSNews Face The Nation...
# 5     2015-10-25 16:11:58  .@CBSNews Poll - WOW!  New Hampshire  TRUMP 38...
# 6     2015-10-25 17:53:31  Do you believe that @FoxNews is still playing ...
# 7     2015-10-25 18:36:34  .@ByronYork  Great numbers from @CBSNews Poll....
# 8     2015-10-25 18:46:26  "@thatgirlflorida: @realDonaldTrump @ByronYork...
# 9     2015-10-25 18:54:50  "@concerningtimes: @JebBush needs to drop out ...
# 10    2015-10-25 18:55:36  "@Tirolian2: @realDonaldTrump @ByronYork @CBSN...
# ...

# %%
# Actual method for cleaning the text
from nltk.tokenize import WordPunctTokenizer
tok = WordPunctTokenizer()
pat1 = r'@[A-Za-z0-9]+'
pat2 = r'https?://[A-Za-z0-9./]+'
combined_pat = r'|'.join((pat1, pat2))


def tweet_cleaner(text):
    soup = BeautifulSoup(text, 'lxml')
    souped = soup.get_text()
    stripped = re.sub(combined_pat, 'https', souped)
    try:
        clean = stripped.decode("utf-8-sig").replace(u"\ufffd", "?")
    except:
        clean = stripped

    # Do we want to do something for links etc?
    
    letters_only = re.sub("[^a-zA-Z]", " ", stripped)
    lower_case = letters_only.lower()

    words = tok.tokenize(lower_case)
    return (" ".join(words)).strip()

# %%
# Make the cleaned dataframe
def make_clean_df(df):
    print("Cleaning and parsing the tweets...\n")
    clean_texts = []
    for i in range(0, len(df)):
        if( (i+1)%1000 == 0 ):
            print(i+1, " tweets has been processed")                                                                  
        clean_texts.append(tweet_cleaner(df['text'][i]))
    clean_df = pd.DataFrame(clean_texts,columns=['text'])
    clean_df['timestamp'] = df.created_at
    clean_df['tweet'] = df.text
    return clean_df

# %%
clean_df = make_clean_df(df)
clean_before = make_clean_df(df_before)
clean_after = make_clean_df(df_after)
# Out:
# Cleaning and parsing the tweets...
# /home/venla/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "http://t.co/PtViAyrO4A" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# 1000  tweets has been processed
# 2000  tweets has been processed
# 3000  tweets has been processed
# /home/venla/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://t.co/T5JBFXOz3F" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# 4000  tweets has been processed
# ...

# %%
# Checking the dataframes
print(len(clean_df))
print(len(clean_before))
print(len(clean_after))
# Out:
# 13132
# 5339
# 5339

# %%
clean_after.head()
# Out:
#                                                 text            timestamp  \
# 0  thank you pennsylvania going to new hampshire ...  2016-11-08 00:08:28
# 1  today in florida i pledged to stand with the p...  2016-11-08 00:16:15
# 2  big news to share in new hampshire tonight pol...  2016-11-08 00:17:57
# 3  unbelievable evening in new hampshire thank yo...  2016-11-08 03:43:54
# 4  rt https https in michigan this is your moveme...  2016-11-08 04:27:18
#
#                                                tweet
# 0  Thank you Pennsylvania! Going to New Hampshire...
# 1  Today in Florida, I pledged to stand with the ...
# 2  Big news to share in New Hampshire tonight! Po...
# 3  Unbelievable evening in New Hampshire - THANK ...
# 4  RT @detroitnews: .@IvankaTrump in Michigan: ‘T...

# %%
# Write the .json-files
with open('../data/clean_tweets/clean_tweets.json', 'w') as file:
    file.write(clean_df.to_json(orient='index'))
    
with open('../data/clean_tweets/clean_tweets_before.json', 'w') as file:
    file.write(clean_before.to_json(orient='index'))

with open('../data/clean_tweets/clean_tweets_after.json', 'w') as file:
    file.write(clean_after.to_json(orient='index'))

# %%
# Test if the json is readable
with open('../data/clean_tweets/clean_tweets_after.json', 'r') as file:
    testi = pd.read_json(file, orient='index')

# %%
testi.describe()
# Out:
#          text            timestamp                      tweet
# count    5339                 5339                       5339
# unique   5174                 5272                       5283
# top     https  2018-07-15 13:33:15  MAKE AMERICA GREAT AGAIN!
# freq       37                    5                          9
# first     NaN  2016-11-08 00:08:28                        NaN
# last      NaN  2018-09-26 10:57:30                        NaN

# %%
testi.head()
# Out:
#                                                 text           timestamp  \
# 0  thank you pennsylvania going to new hampshire ... 2016-11-08 00:08:28
# 1  today in florida i pledged to stand with the p... 2016-11-08 00:16:15
# 2  big news to share in new hampshire tonight pol... 2016-11-08 00:17:57
# 3  unbelievable evening in new hampshire thank yo... 2016-11-08 03:43:54
# 4  rt https https in michigan this is your moveme... 2016-11-08 04:27:18
#
#                                                tweet
# 0  Thank you Pennsylvania! Going to New Hampshire...
# 1  Today in Florida, I pledged to stand with the ...
# 2  Big news to share in New Hampshire tonight! Po...
# 3  Unbelievable evening in New Hampshire - THANK ...
# 4  RT @detroitnews: .@IvankaTrump in Michigan: ‘T...
