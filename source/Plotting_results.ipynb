# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# Make plots bigger
matplotlib.rcParams['figure.figsize'] = (10.0, 5.0)

# %%
all_model = 45.4
before_model = 26.8
after_model = 25.6
random = 16.7

# %%
y = [all_model, before_model, after_model, random]
labels = ['all tweets', 'before', 'after', 'random']

# %%
x = np.arange(4)
plt.bar(x, height=y)

#x, height= y
plt.xticks(x+.10, labels);

# %%
x = np.arange(4)
plt.bar(x, height=y)

#x, height= y
plt.xticks(x, labels);

# %%
plt.bar(x,y)
plt.xticks(x, labels)
plt.title("Right predictions (% of all)")

offset_x = -0.1
offset_y = 0.5

for a,b in zip(x,y):
    plt.text(a + offset_x, b + offset_y, str(b), fontweight="bold")

    
#plt.show()

#save to file
path = "../files/presentation/images/test.svg"
plt.savefig(path, dpi=300, format='svg', bbox_inches='tight') # use format='svg' or 'pdf' for vectorial pictures
